# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import copy
from data8 import x,y,z,data
from detect import distance,get_W, get_D,knn_laplace, min_k_index

# %%
# plot data1
ax = plt.subplot(111, projection='3d')
ax.scatter(x,y,z)

# %%
knn=knn_laplace(data,20)

# %%
u,v=np.linalg.eig(knn)
u=np.abs(np.real(u))
v=np.real(v)

# %%
min_k_index(u,2)
# Out:
# 1

# %%
ax = plt.subplot(111, projection='3d')
ax.scatter(x,y,z,c=v[:,1])
