# %%
import numpy as np
from planeData import data,x,y,z
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
from localPista import LocalRegressor
from mpl_toolkits.mplot3d import Axes3D
from laplace import get_laplace, knn_laplace,extend_knn,cordinate, distance
from kMeans import kMeans, min_k_index, max_k_index
from newLocalL1 import locaL
import copy

# %%
ax=plt.subplot(111,projection='3d')
ax.scatter(x,y,z)

# %%
n_sample=len(data[0])
n_feature=len(data)

# %%
alpha=0.01
beta=0.001
K=200
k1=100
k2=800
epsilon=0.5

# %%
indexs=np.random.choice(range(n_feature),K)
B=np.zeros((n_feature,n_feature))

# %%
B=locaL(data,indexs,B,alpha,beta)
B=np.abs(B)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-320c9beb152a> in <module>
# ----> 1 B=locaL(data,indexs,B,alpha,beta)
#       2 B=np.abs(B)
#
# ~\Documents\research\local_l1\newLocalL1.py in locaL(data, indexs, B, alpha, beta)
#      42         Y=np.array(data[index])
#      43         oscar_owl = LocalRegressor(alpha,beta)
# ---> 44         oscar_owl.fit(X,Y)
#      45         B=store(oscar_owl.coef_,B,index)
#      46     return B
#
# ~\Documents\research\local_l1\localPista.py in fit(self, X, y)
#     124         self.coef_ = _fit_local_fista(X, y, alpha, beta, loss, self.max_iter,
#     125                                     self.max_linesearch, self.eta, self.tol,
# --> 126                                     self.verbose)
#     127         return self
#     128
#
# ~\Documents\research\local_l1\localPista.py in _fit_local_fista(X, y, alpha, beta, loss, max_iter, max_linesearch, eta, tol, verbose)
#      53     coef = np.zeros(X.shape[1])
#      54     return fista(sfunc, nsfunc, coef, max_iter, max_linesearch,
# ---> 55                  eta, tol, verbose)
#      56
#      57
#
# ~\Documents\research\local_l1\fista.py in fista(sfunc, nsfunc, x0, max_iter, max_linesearch, eta, tol, verbose)
#      23         for ls in range(max_linesearch):
#      24             y_proj = nsfunc(y - grad / L, L)
# ---> 25             diff = (y_proj - y).ravel()
#      26             sqdist = np.dot(diff, diff)
#      27             dist = np.sqrt(sqdist)
#
# ValueError: operands could not be broadcast together with shapes (3,) (999,)
